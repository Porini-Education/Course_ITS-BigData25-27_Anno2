# %% [markdown]
# ## Greek run

# %% [markdown]
# In this exercise you will use numpy and matplotlib to simulate the greek run. The greek run works as follows:
# - There are 5 players(1,2,3,4,5) at positions 0,20,40,60,80
# - Players 1,2,3,4 are moving towards the right and player 5 is moving towards the left
# - If 2 players meet they both switch directions they are running
# - If a player's position is below 0 or above 100, they are safe
# - The last player to exit looses
#
# Which player looses?

# %%
# %pip install matplotlib numpy
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.2-cp314-cp314-win_amd64.whl.metadata (80 kB)
# Collecting numpy
#   Downloading numpy-2.5.3-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.4.0-cp314-cp314-win_amd64.whl.metadata (3.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.65.0-cp314-cp314-win_amd64.whl.metadata (127 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.1-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\Users\WilliamRussell\github\Course_ITS-BigData25-27_Anno2\.venv\Lib\site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\WilliamRussell\github\Course_ITS-BigData25-27_Anno2\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\WilliamRussell\github\Course_ITS-BigData25-27_Anno2\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.2-cp314-cp314-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------------------- -------------------- 4.7/9.5 MB 23.7 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 24.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 16.4 MB/s  0:00:00
# Downloading numpy-2.5.3-cp314-cp314-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ------------------ --------------------- 6.0/12.7 MB 29.8 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.7 MB 27.7 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.7 MB 24.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 15.1 MB/s  0:00:00
# Downloading contourpy-1.4.0-cp314-cp314-win_amd64.whl (240 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.65.0-cp314-cp314-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 16.9 MB/s  0:00:00
# Downloading kiwisolver-1.5.1-cp314-cp314-win_amd64.whl (72 kB)
# Downloading pillow-12.3.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------- ----------- 5.2/7.2 MB 26.1 MB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 16.9 MB/s  0:00:00
# Downloading pyparsing-3.3.3-py3-none-any.whl (126 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    ------------------------- -------------- 5/8 [cycler]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ---------------------------------------- 8/8 [matplotlib]
#
# Successfully installed contourpy-1.4.0 cycler-0.12.1 fonttools-4.65.0 kiwisolver-1.5.1 matplotlib-3.11.2 numpy-2.5.3 pillow-12.3.0 pyparsing-3.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import numpy as np
from IPython import display

# %%
# Step 1
# - Create the line with the correct positions as an np.array
# - Assign a True if the player is still playing to each player as an np.array
# - Assign a direction to each player as an np.array
# - choose 5 colors for the players
# - choose 5 markers for the players
# - Using for x in zip(posizioni,direction,colors,markers): , plot: the initial positions, the the x limit from 0-100, set the y limit from -0.2 - 0.2

posizioni= np.array([0,20,40,60,80])
play= np.array([True,True,True,True,True])
direction= np.array([1,1,1,1,-1])
colors= ['r','g','b','c','m']
markers= ['o','v','^','<','>']

fig=plt.figure();
ax = fig.add_axes((0, 0, 1, 1));
fig.suptitle('Greek Run',fontsize=14)

def plot_players(ax, posizioni, colors, markers):
    
    # for x in zip(posizioni,colors,markers):
    #     pos = x[0]
    #     col = x[1]
    #     mark = x[2]

    for pos, col, mark in zip(posizioni,colors,markers):
        ax.plot(pos,0,color=col,marker=mark,markersize=15)
        ax.grid()
        ax.set_xlim(0,100)
        ax.set_ylim(-0.2,0.2)
        ax.set_yticks([0])
        ax.set_yticklabels(['Run'])

plot_players(ax, posizioni, colors, markers)

display.clear_output(wait=True)
display.display(plt.gcf())
time.sleep(1.0)

step = 0

while len(play[play==True]) > 1:
    step += 1
    # Step 2
    # - add a step in the correct direction to each player
    # - Check whether any players are out of the game
    # - Check if some players have met, if they did, change their direction
    posizioni = posizioni + direction
    play[posizioni < 0] = False
    play[posizioni > 100] = False

    for i in range(len(posizioni)-1):
        if posizioni[i] == posizioni[i+1] and play[i] and play[i+1]:
            direction[i] = -direction[i]
            direction[i+1] = -direction[i+1]
            # direction[i], direction[i+1] = direction[i+1], direction[i]

    ax.clear()
    
    # Step 3
    # - Plot the new positions using the code from step 1
    plot_players(ax, posizioni, colors, markers)
       
    display.clear_output(wait=True)
    display.display(plt.gcf())
    time.sleep(0.2)

display.clear_output()
display.display(plt.gcf())
display.clear_output()


# Step 4
# - Count the remaining steps for the last player
# - calculate the total number of steps
# - print the total amount of steps.
if direction[play==True] == 1:
    step_last=100-posizioni[play==True]
else:
    step_last=posizioni[play==True]

tot_step=step+step_last[0]

print("Steps before last player:",step)
print("Total steps:",tot_step)
# Out:
# Steps before last player: 81
# Total steps: 100
